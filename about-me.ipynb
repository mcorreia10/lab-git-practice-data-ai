# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Marcelo Correia"
reason = "I want to transition from mechanical engineering to software and AI development and build real digital products"
fun_fact = "I play football, go to the gym and I am very curious about technology"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Marcelo Correia. I’m excited to learn because I want to transition from mechanical engineering to software and AI development and build real digital products. A fun fact about me is: I play football, go to the gym and I am very curious about technology.
